# %% [markdown]
# # Lecture 8 Worksheet

# %% [markdown]
# ## Recap

# %% [markdown]
# In the seventh lecture, we:
#
# - Discussed strategies for speeding up our dashboards
# - Practiced callbacks with DashR
# - Did some case studies of super effective/awesome dashboards!

# %% [markdown]
# **(Update: app5 was added prior to Lecture 8)**
#
# All four apps we will be going through in Lecture are created here:
#
# - [**app1.R:**](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app1.R) - Basic framework in DashR
# - [**app2.R:**](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app2.R) - Switch to gapminder dataset and slightly more complex plots
# - [**app2_animated.R:**](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app2_animated.R) - Animated gapminder plot
# - [**app3.R:**](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app3.R) - Adding components to our DashR app
# - [**app4.R:**](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app4.R) - Full interactivity including an interactive table
# - [**app5.R:**](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app5.R) - Linked charts in R (optional, by popular demand)

# %% [markdown]
# ## Today's agenda

# %% [markdown]
# ## No coding today in lecture!
#
# (unless you want to, in which case try to implement Linked Charts in [app5.R](https://github.com/firasm/dash_demo/blob/master/R/Class%20App/app5.R))

# %% [markdown]
# - Part 1: Student questions [40 mins]
# - Teaching Evalations for DSCI 532 [10 mins]
# - Part 2: Best of 532 Dashboards[20 mins]
# - Part 3: Final thoughts [20 mins]

# %% [markdown]
# ## Part 1 - Student questions

# %% [markdown]
# ## Part 2 - Teaching Evaluations

# %% [markdown]
# ## Part 3 - Best of 532 Dashboards

# %% [markdown]
# Here are the TA selected top 11 dashboards (in no particular order):
#
# - 1 -  https://dsci-532-group102-milestone3.herokuapp.com/
# - 2 - https://dsci-532-group108-milestone3.herokuapp.com/
# - 3 - https://dsci-532-group203-maintenance.herokuapp.com
# - 4 - https://dsci-532-l02-gr212-milestone3.herokuapp.com
# - 5 - https://dsci532group114milestone3.herokuapp.com/
# - 6 - https://g105-milestone3.herokuapp.com/
# - 7 - https://group-106-post-maintenance-app.herokuapp.com/
# - 8 - https://group204-vino-milestone2.herokuapp.com
# - 9 - https://pollutantsmatterbc.herokuapp.com
# - 10 - https://risk-factors-of-death-2.herokuapp.com
# - 11 - https://world-wide-weapons-report.herokuapp.com/

# %% [markdown]
# Select your 3 favourite dashboards based on the principles of effective design principles
#
# | Principle | Feedback |
# | --------- | -------- |
# | Audience matters | |
# | Purpose-driven dashboards | |
# | Choose defaults wisely | |
# | Less is more | |
# | Add a narrative and signposts | |
# | Aesthetics matter | |
# | Build trust in your analysis | |
# | Think about the "onboarding" experience | |
# | Use a consistent layout | |
# | Use animations sparingly | |
# | Allow users to filter data (if applicable) | |
# | User testing is critical | |
