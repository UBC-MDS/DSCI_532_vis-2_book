# %%
### Step X

Create a folder called `assets` where your `app2.py` file is loaded.

1. Inside this folder, create a new file called `typography.css` and add the following lines to it:

body {
    font-family: sans-serif;
}
h1, h2, h3, h4, h5, h6 {
    color: hotpink
}

2. In the same `assets` folder, create a new file called `typography.css`
