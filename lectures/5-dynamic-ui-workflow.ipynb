# %% [markdown]
# # DSCI 532 - Lecture 4
# ## Development workflow, debbuging,and advanced reactivity

# %% [markdown]
# ---
#
# **Learning objectives**
#
# 1. Debug an app using the traceback
# 2. Recognize when is needed to implement a dynamic UI
# 3. (Tidyevaluation)
#
# ---

# %% [markdown]
# ## Compare Shiny and Dash
#
# Recommended lecture: [Lyttle, I (2022) Data science reactivity: Three ways](https://ijlyttle.github.io/reactivity-three-ways-quarto/)

# %% [markdown]
# ## 1. Debug an app
#
# - [Chapter 5 section 2 - Debugging - Mastering Shiny](https://mastering-shiny.org/action-workflow.html#debugging)

# %% [markdown]
# ## 2. Dynamic UI
#
# - [Chapter 10 - Dynamic UI - Mastering Shiny](https://mastering-shiny.org/action-dynamic.html)

# %% [markdown]
# ## 3. Tidyevaluation
#
# *This section is only relevant if you are using the R packages that belongs to the tidyverse*
#
# - [Chapter 12 - Tidyevaluation](https://mastering-shiny.org/action-tidy.html)

# %% [markdown]
# # References
#
# - Fay, C., Rochette, S., Guyader, V., & Girard, C. (2021). Engineering Production-Grade Shiny Apps. Chapman and Hall/CR.
#
# - Granjon, D. (2022). Outstanding User Interfaces with Shiny. CRC Press
#
# - Rasmussen, N. H., Bansal, M., & Chen, C. Y. (2009). Business dashboards: a visual catalog for design and deployment. John Wiley & Sons.
#
# - Sievert, C. (2020). Interactive web-based data visualization with R, plotly, and shiny. CRC Press.
#
# - Wickham, H. (2021). Mastering shiny. " O'Reilly Media, Inc.".
