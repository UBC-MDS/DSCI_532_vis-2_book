# %% [markdown]
# # Data Visualization II
# ## Comments about the book

# %% [markdown]
# ### How is the material organized?
#
# In this book you will find the link to the slides, that will be uploaded after the lectures. There will practise using activities as iClicker and activities during the class.
#
# The chapters of this Jupyter Book are mostly guidance to the documentation and book chapters where you will find detailed tutorials or information about the specific topics developed during the course.
#
# The complete this to the materials used to develop this course is the following one:
#
# - Fay, C., Rochette, S., Guyader, V., & Girard, C. (2021). Engineering Production-Grade Shiny Apps. Chapman and Hall/CR.
#
# - Granjon, D. (2022). Outstanding User Interfaces with Shiny. CRC Press
#
# - Rasmussen, N. H., Bansal, M., & Chen, C. Y. (2009). Business dashboards: a visual catalog for design and deployment. John Wiley & Sons.
#
# - Sievert, C. (2020). Interactive web-based data visualization with R, plotly, and shiny. CRC Press.
#
# - Wickham, H. (2021). Mastering shiny. " O'Reilly Media, Inc.".
