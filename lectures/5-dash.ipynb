# %% [markdown]
# # DSCI 532 - Lecture5
# ## Dash

# %% [markdown]
# ---
# **Learning outcomes**
#
# 1. Compare Shiny and Dash packages
# 2. Create a Dash python app
# 3. Explain the concept of WebAssembly
# ---

# %% [markdown]
# ## 1. Compare Shiny and Dash
#
# Recommended lecture: [Lyttle, I (2022) Data science reactivity: Three ways](https://ijlyttle.github.io/reactivity-three-ways-quarto/)

# %% [markdown]
# ## 2. Create a Dash python app

# %% [markdown]
# ## 3. WebAssembly
