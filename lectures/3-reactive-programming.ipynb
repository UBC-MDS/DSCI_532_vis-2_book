# %% [markdown]
# # DSCI 532 - Lecture3
# ## Reactive programming

# %% [markdown]
# ---
# **Learning objectives**
#
# 1. Explain the concept of reactive programming
# 2. Interpret a reactive graph
# 3. Incorpore reactive expressions to avoid code duplication
# 4. Implement and differenciate observers and outputs
# 5. Avoid creating reactive dependencies when needed: `isolate()`, `observeEvent()` and `eventReactive()`
# *example adding a button*
# ---

# %% [markdown]
# ## 1. What is reactive programming?
#
# > **Reactive programming** is a style of programming that focuses on values that change over time, and calculations and actions that depend on those values. Reactivity is important for Shiny apps because they’re interactive: users change input controls (dragging sliders, typing in textboxes, checking checkboxes, …) which causes logic to run on the server (reading CSVs, subsetting data, fitting models, …) ultimately resulting in outputs updating (plots redrawing, tables updating, …). This is quite different from most R code, which typically deals with fairly static data.
#
# Quote extracted from [Chapter 13 - Why reactivity? - Mastering Shiny](https://mastering-shiny.org/reactive-motivation.html#motivation)
#
# #### 1.1 Understanding more complex servers in Dash and Shiny
#
# - callback functions

# %% [markdown]
# ## 2. Interpret a reactive graph
#
# **Shiny**
# [Chapter 14 - The reactive graph - Mastering Shiny](https://mastering-shiny.org/reactive-graph.html)
#
# **Dash**

# %% [markdown]
# ## 3. Incorpore tractive expressions to avoid code duplication
#
# - [Chapter 1 section 6 - Reducing duplication with reactive expressions](https://mastering-shiny.org/basic-app.html#reactive-expr)

# %% [markdown]
# ## 4. What is an observer?
#
# [Chapter 15 section 3 - Observers and outputs - Mastering Shiny](https://mastering-shiny.org/reactivity-objects.html#observers-details)

# %% [markdown]
# ## 5. Isolate your code
#
# [Chapter 15 section 4 - Isolate your code - Mastering Shiny](https://mastering-shiny.org/reactivity-objects.html#observers-details)

# %% [markdown]
# # References
#
# - Fay, C., Rochette, S., Guyader, V., & Girard, C. (2021). Engineering Production-Grade Shiny Apps. Chapman and Hall/CR.
#
# - Granjon, D. (2022). Outstanding User Interfaces with Shiny. CRC Press
#
# - Rasmussen, N. H., Bansal, M., & Chen, C. Y. (2009). Business dashboards: a visual catalog for design and deployment. John Wiley & Sons.
#
# - Sievert, C. (2020). Interactive web-based data visualization with R, plotly, and shiny. CRC Press.
#
# - Wickham, H. (2021). Mastering shiny. " O'Reilly Media, Inc.".
