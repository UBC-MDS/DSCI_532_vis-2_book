# %% [markdown]
# # DSCI 532 - Lecture1
# ## Introduction to Data Vizualization II - What is a dashboard?

# %% [markdown]
# ---
# **Learning objectives**
#
#
# 1. Define what is a dashboard
#
# 2. Differentiate reactivity and interactivity
#
# 3. Identify the **server** and the **user interface** as the core elements that compose a dashboard
#
# 4. Implement the **reactivity** connecting the server and the user interface using specific functions
#
# 5. Create and run a basic Shiny R app
#
#
# ---

# %% [markdown]
# ## 1. What is a Dashboard?

# %% [markdown]
# ### 1.1 What technology to use?
#
# There are many popular technologies available to create dashboards for data scientists. Tableau, Streamlite, Voila, Shiny, Dash, Power BI, and many more.

# %% [markdown]
# ---
#
# Is a dashboard a web app?
#
# ---

# %% [markdown]
# ## 2. Interactivity and Reactivity
#
# ### 2.1 Interactivity
#
# ### 2.2 Reactivity

# %% [markdown]
# ---
#
# What are the benefits of using an interactive plot in a dashboard without having to set reactivity?
#
# ---

# %% [markdown]
# ## 3. Dashboard core components
#
# In general dashboards have 2 components:
#
# - **User Interface (UI)**
# Define how your app look. It is also called *frontend*
#
# > What does UX stands for?
#
# - **Server**
# Define how your app works. It is also called *backend*

# %% [markdown]
# ## 4. Connect the server and the user interface

# %% [markdown]
# ## 5. Run and deploy your first Shiny app!
#
# - The live code in the class will be based in the chapter ["Your first Shiny app" in Mastering Shiny](https://mastering-shiny.org/basic-app.html)

# %% [markdown]
# # References
#
# - Fay, C., Rochette, S., Guyader, V., & Girard, C. (2021). Engineering Production-Grade Shiny Apps. Chapman and Hall/CR.
#
# - Granjon, D. (2022). Outstanding User Interfaces with Shiny. CRC Press
#
# - Rasmussen, N. H., Bansal, M., & Chen, C. Y. (2009). Business dashboards: a visual catalog for design and deployment. John Wiley & Sons.
#
# - Sievert, C. (2020). Interactive web-based data visualization with R, plotly, and shiny. CRC Press.
#
# - Wickham, H. (2021). Mastering shiny. " O'Reilly Media, Inc.".
