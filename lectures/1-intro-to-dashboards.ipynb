# %% [markdown]
# # Intro to dashboards

# %% [markdown]
# ::::: {.grid}
#
# :::: {.g-col-6}
#
# ::: {.callout-note appearance="minimal"}
# ## Lecture learning goals
#
# 1. Understand what dashboards are
# 2. Explain the advantages of using dashboards
# 3. Define what constitutes an effective dashboard layout
# 4. Explain the advantages of using interactive visualizations
# 5. Distinguish server side from client side interactivity
#
# :::
#
# ::::
#
# :::: {.g-col-6}
#
# ::: {.callout-note appearance="minimal"}
# ## Required activities
#
# - [Don't rush into coding](https://engineering-shiny.org/dont-rush-into-coding.html#dont-rush-into-coding) Sections 7.1.1, 7.2.1, 7.2.2.
# - [UX Matters](https://engineering-shiny.org/ux-matters.html#ux-matters) Sections 6, 6.1, 6.1.1 (until the first code chunk), 6.1.2.
#
# *You can read these either before or after class*
#
# :::
#
# ::::
#
# :::::

# %% [markdown]
# **Lecture slides**
#
# ![](slides-lec1.pdf#zoom=75&&navpanes=0&statusbar=0&messages=0&pagemode=none){width=100% height=440px}
