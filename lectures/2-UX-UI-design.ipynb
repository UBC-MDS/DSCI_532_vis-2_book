# %% [markdown]
# # DSCI 532 - Lecture2
# ## UX and UI design

# %% [markdown]
# ---
#
# **Learning objectives**
#
# 1.  Recognize the importance of user center design when developing a dashboard
#
# 2.  Implement the six steps to design an app
#
# 3.  Distiguish the different types of dashboards in relation to their UI design (step 3)
#
# 4.  Customize the app appearance using boostrap themes (step 4)
#
# 5.  Design a prototype of an app the user's needs creating personas profiles
#
# ---

# %% [markdown]
# ## Why is user center design so important?
#
# ### UX matters
# > "Let’s state the truth: no matter how complex and innovative your back-end is, your application is bad if your user experience (UX) is bad. That’s the hard truth. We have a natural tendency, as R-coders, to be focused on the back-end, i.e. the server part of the application, which is perfectly normal—chances are you did not come to R to design front-ends.
# > However, **if people cannot understand how to use your application, or if your application front-end does not work at all, your application is not successful no matter how innovative and incredible the computation algorithms in the back-end are**.
# > As you are building a complex, production-grade shiny application, do not underestimate the necessity for a successful front-end - it is, after all, the first thing (and probably the only thing) that the end users of your web application will see. However, our natural back-end/server logic as R developers can play against us in the long run - **by neglecting the UI and the UX, you will make your application less likely to be adopted among your users, which is a good way to fail your application project.**"
#
# Quote extracted from [Chapter 6: UX matters - Engineering Production-Grade Shiny Apps](https://engineering-shiny.org/ux-matters.html)

# %% [markdown]
# ## Six steps to **design** a dashboard
#
# #### Step 1. [Get to know well your *Persona*](https://engineering-shiny.org/dont-rush-into-coding.html#building-personas)
# - [Ask questions](https://engineering-shiny.org/dont-rush-into-coding.html#ask-questions)
#
# #### Step 2. Decide on Dashboard Categories.
# 1.  Tactic
# 2.  Operational
# 3.  Strategic
# - Strategic
# - Operational
# - Analytic
#
# #### Step 3. Create a List of KPIs and Metrics for Each Strategic Objective and select the most appropiated ones
#
# #### Step 4. Choose Presentation Method and Interactivity for Each KPI
#
# **i. Gather all components available in the chosen dashboard technology.**
# -   Charts
# -   Gauges
# -   Traffic lights, arrows, and other indicators
# -   Interactivity for drill down, annotations, actions ( e.g., approvals)
# -   Alerts
# -   Maps
#
# **ii. Design dashboard layout.**
# -   [Accesibility](https://engineering-shiny.org/ux-matters.html#making-your-app-accessible)
# -   [Themes](https://mastering-shiny.org/action-layout.html#themes)
# -   Fonts and size
# -   Colors
# -   [Do we need more than one dashboard?](https://engineering-shiny.org/ux-matters.html#the-danger-of-feature-creep)
# -   Are components that can be collapsed / expanded?
#
# > [**Does the organization has a particular color and layout scheme desired for the dashboards?**](https://engineering-shiny.org/css.html)
#
# **iii. Assign dashboard title and component labels**
# **iv. Specify core dashboard functionality**
#
# #### Step 5. Create a sketch of the dashboard (or [prototype](https://engineering-shiny.org/building-ispum-app.html))
#
# #### Step 6. Document Decisions and show the sketch/[prototype](https://engineering-shiny.org/building-ispum-app.html) for approval

# %% [markdown]
# # References
#
# - Fay, C., Rochette, S., Guyader, V., & Girard, C. (2021). Engineering Production-Grade Shiny Apps. Chapman and Hall/CR.
#
# - Granjon, D. (2022). Outstanding User Interfaces with Shiny. CRC Press
#
# - Rasmussen, N. H., Bansal, M., & Chen, C. Y. (2009). Business dashboards: a visual catalog for design and deployment. John Wiley & Sons.
#
# - Sievert, C. (2020). Interactive web-based data visualization with R, plotly, and shiny. CRC Press.
#
# - Wickham, H. (2021). Mastering shiny. " O'Reilly Media, Inc.".
