# %% [markdown]
# # DSCI 532 Lecture8
# ## Reports and user feedback

# %% [markdown]
# ---
#
# **Learning objectives**
#
# 1. Include a parameterized report in the dashboard using Rmarkdown
# 2. Support users provinding real time documentation as progrss bars, notifications and alerts.
# 3. `req()`
#
# ---

# %% [markdown]
# ## 1. Parametrized reports with Shiny and Rmarkdown
#
# - [Chapter 9 section 2.3 - Downloading reports](https://mastering-shiny.org/action-transfer.html?q=report#downloading-reports)

# %% [markdown]
# ## 2. User feedback
#
# - [Chapter 8 - User feedback - Mastering Shiny](https://mastering-shiny.org/action-feedback.html)
