# %% [markdown]
# # DSCI 532 Lecture7
# ## Testing, performance, dependency managment and CI/CD

# %% [markdown]
# ---
#
# **Learning objectives**
#
# 1. Recognize the different types of testing available for dashboards
# 2.Explore strategies to improve the dashboard performance
# 3. Configure a Dockerfile to ensure the app reproducibility
# 4. Set continuos integration (CI) and continous deployment (CD) for the dashboard
#
# ---

# %% [markdown]
# ## 1. Testing
#
#
# - [Chapter 21 - Testing - Mastering Shiny](https://mastering-shiny.org/scaling-testing.html)

# %% [markdown]
# ## 2. Performance
#
# #### 2.1 Caching (Shiny)
#
# - [Chapter 23 - Performance](https://mastering-shiny.org/performance.html)
#
# #### 2.2 Caching (Dash)

# %% [markdown]
# ## 3. Continous Integration (CI) and Continuos Deployment CD
#
# - [Chapter 17 section 4 - Dependency Managment - Mastering Shiny](https://mastering-shiny.org/best-practices.html#dependency-management)
# - [Chapter 17 section 6 - CI/CD - Mastering Shiny](
# https://mastering-shiny.org/best-practices.html#continuous-integrationdeployment-ci-cd)

# %% [markdown]
# https://github.com/miraisolutions/ShinyCICD
