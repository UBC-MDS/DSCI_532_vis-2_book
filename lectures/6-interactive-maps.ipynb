# %% [markdown]
# # DSCI 532 - Lecture6
# ## Interactive maps

# %% [markdown]
# ---
#
# **Learning objectives**
#
# 1.  Compare `plotly`, `leafleat` and `altair` for map creation.
#
# 2.  Insert a leaflet map in a Dashboard
#
# 3.  Insert a plotly map in a Dashboard
#
# ---

# %% [markdown]
# ## 1. Interactive plots
#
# ## 2. Interactive maps: what is different between Plotly, leafleat and altair?
#
# #### 2.1 Plotly
#
# #### 2.2 Leaflet
